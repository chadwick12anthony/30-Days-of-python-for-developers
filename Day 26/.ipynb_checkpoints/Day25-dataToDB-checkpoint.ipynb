# %%
# !pip install pandas sqlalchemy sqlacodegen
# Out:
# Requirement already satisfied: pandas in /Users/anthonychadwick/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: sqlalchemy in /Users/anthonychadwick/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages (2.0.48)
# Collecting sqlacodegen
#   Downloading sqlacodegen-4.0.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/anthonychadwick/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anthonychadwick/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/anthonychadwick/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages (from sqlalchemy) (4.15.0)
# Collecting inflect>=4.0.0 (from sqlacodegen)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting more_itertools>=8.5.0 (from inflect>=4.0.0->sqlacodegen)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect>=4.0.0->sqlacodegen)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/anthonychadwick/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading sqlacodegen-4.0.3-py3-none-any.whl (27 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Installing collected packages: typeguard, more_itertools, inflect, sqlacodegen
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [sqlacodegen]
# Successfully installed inflect-7.5.0 more_itertools-10.8.0 sqlacodegen-4.0.3 typeguard-4.5.1

# %%
import pickle # pickel can remember the change in the file bt csv can't
import pandas as pd

# %%
data = [{"name": "Peace"}]

with open("users.pkl", 'wb') as f:
    pickle.dump(data, f) # pickle.dump

# %%
data_from_pkl = pickle.load(open('users.pkl', 'rb')) # pickle.loads -> pickle.load
print(data_from_pkl, type(data_from_pkl))
# Out:
# [{'name': 'Peace'}] <class 'list'>

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#     name
# 0  Peace

# %%
df.to_pickle("df_pkl")
df.dtypes
# Out:
# name    str
# dtype: object

# %%
df2 = pd.read_pickle("df_pkl")
df2.head()
# Out:
#     name
# 0  Peace

# %%
df2.dtypes
# Out:
# name    str
# dtype: object

# %%
df.to_csv("my_df.csv", index=False)

# %%
from dataclasses import dataclass

@dataclass
class Author():
    name:str = "Dasha"
    genre:str = "sci-fi"
    year:int = None
    
# class Author():
#     name = "Dasha"
#     def __init__(self, name="Raw", *args, **kwargs):
#         super().__init__(*args, **kwargs)
#         self.name = name

@dataclass
class Movie:
    name:str = 'Unknown'
    genre:str = 'Action'
    year:int = None

# %%
my_movie = Author()
my_movie.name = "Dasha Kravets"
my_movie.name
# Out:
# 'Dasha Kravets'

# %%
data = [{
    "name": "Interstellar",
    "genre": "Sci-Fi"
},
{
    "name": "The Martian",
    "genre": "Sci-Fi"
},
{
    "name": "Arrival",
    "genre": "Sci-Fi"
}
]

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#            name   genre
# 0  Interstellar  Sci-Fi
# 1   The Martian  Sci-Fi
# 2       Arrival  Sci-Fi

# %%
import sqlalchemy
from sqlalchemy import Column, Integer, String
from sqlalchemy import create_engine, Column, String, Integer
from sqlalchemy.orm import sessionmaker

# %%
engine = create_engine("sqlite:///app.db") # mysql, postgres

# %%
Session = sessionmaker(bind=engine) # just for the db to not be always active 
my_sess = Session()

# %%
#from sqlalchemy.ext.declarative import declarative_base # 4 our table to not be treated as an obj by python
from sqlalchemy.orm import declarative_base
Base = declarative_base()

# %%
class Movie(Base): # table
    __tablename__ = "movies"
    
    id = Column(Integer, primary_key=True) # auto created for us
    name = Column(String) # 'Unknown' # col
    genre = Column(String) # 'Action' # col
    description = Column(String) # 'Action' # col
    year = Column(Integer, nullable=True) # None # col
    
    #__repr__ method defines how a Movie object appears when printed or viewed in the Python interpreter.
    def __repr__(self):
        return f"<Movie name = {self.name}>"
        
# saved instance = row
# Out:
# /var/folders/47/_j9368zd10z7q7_1hgrl5m0r0000gn/T/ipykernel_2339/136296623.py:1: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Movie, and will be replaced in the string-lookup table.
#   class Movie(Base): # table
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 class Movie(Base): # table
#       2     __tablename__ = "movies"
#       4     id = Column(Integer, primary_key=True) # auto created for us
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/orm/decl_api.py:199, in DeclarativeMeta.__init__(cls, classname, bases, dict_, **kw)
#     196         cls._sa_registry = reg
#     198 if not cls.__dict__.get("__abstract__", False):
# --> 199     _as_declarative(reg, cls, dict_)
#     200 type.__init__(cls, classname, bases, dict_)
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/orm/decl_base.py:245, in _as_declarative(registry, cls, dict_)
#     240 def _as_declarative(
#     241     registry: _RegistryType, cls: Type[Any], dict_: _ClassDict
#     242 ) -> Optional[_MapperConfig]:
#     243     # declarative scans the class for attributes.  no table or mapper
#     244     # args passed separately.
# --> 245     return _MapperConfig.setup_mapping(registry, cls, dict_, None, {})
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/orm/decl_base.py:326, in _MapperConfig.setup_mapping(cls, registry, cls_, dict_, table, mapper_kw)
#     322     return _DeferredMapperConfig(
#     323         registry, cls_, dict_, table, mapper_kw
#     324     )
#     325 else:
# --> 326     return _ClassScanMapperConfig(
#     327         registry, cls_, dict_, table, mapper_kw
#     328     )
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/orm/decl_base.py:577, in _ClassScanMapperConfig.__init__(self, registry, cls_, dict_, table, mapper_kw)
#     573 self._extract_mappable_attributes()
#     575 self._extract_declared_columns()
# --> 577 self._setup_table(table)
#     579 self._setup_inheriting_columns(mapper_kw)
#     581 self._early_mapping(mapper_kw)
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/orm/decl_base.py:1762, in _ClassScanMapperConfig._setup_table(self, table)
#    1754             table_kw["autoload"] = True
#    1756         sorted_columns = sorted(
#    1757             declared_columns,
#    1758             key=lambda c: column_ordering.get(c, 0),
#    1759         )
#    1760         table = self.set_cls_attribute(
#    1761             "__table__",
# -> 1762             table_cls(
#    1763                 tablename,
#    1764                 self._metadata_for_cls(manager),
#    1765                 *sorted_columns,
#    1766                 *args,
#    1767                 **table_kw,
#    1768             ),
#    1769         )
#    1770 else:
#    1771     if table is None:
#
# File <string>:2, in __new__(cls, *args, **kw)
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:429, in Table.__new__(cls, *args, **kw)
#     422 @util.deprecated_params(
#     423     mustexist=(
#     424         "1.4",
#    (...)    427 )
#     428 def __new__(cls, *args: Any, **kw: Any) -> Any:
# --> 429     return cls._new(*args, **kw)
#
# File ~/.local/share/virtualenvs/Day_26-v2y4vJw6/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:461, in Table._new(cls, *args, **kw)
#     459 if key in metadata.tables:
#     460     if not keep_existing and not extend_existing and bool(args):
# --> 461         raise exc.InvalidRequestError(
#     462             f"Table '{key}' is already defined for this MetaData "
#     463             "instance.  Specify 'extend_existing=True' "
#     464             "to redefine "
#     465             "options and columns on an "
#     466             "existing Table object."
#     467         )
#     468     table = metadata.tables[key]
#     469     if extend_existing:
#
# InvalidRequestError: Table 'movies' is already defined for this MetaData instance.  Specify 'extend_existing=True' to redefine options and columns on an existing Table object.

# %%
# Add table(s) to database
Base.metadata.create_all(engine)

# %%
movie_obj = Movie(name='Interstellar', genre='Sci-Fi')
print(movie_obj , movie_obj.name)
# Out:
# <Movie name=Interstellar> Interstellar

# %%
movie_obj.id

# %%
my_sess.add(movie_obj) # prepare to save
my_sess.commit() # save

# %%
print(movie_obj.id, movie_obj.description)
# Out:
# 1 None

# %%
movie_obj2 = Movie(name='The Martian', genre='Sci-Fi')
print(movie_obj2.name, movie_obj2.id)
# Out:
# The Martian None

# %%
my_sess.add(movie_obj2)

# %%
movie_obj3 = Movie(name='Inception', genre='Sci-Fi')
print(movie_obj3.name, movie_obj3.id)
# Out:
# Inception None

# %%
my_sess.add(movie_obj3)

# %%
my_sess.commit()

# %%
print(movie_obj2.id, movie_obj3.id)
# Out:
# 2 3

# %% [markdown]
# ### CRUD in SQLAlchemy
#
# **Create**
# **Retrieve**
# **Update**
# **Delete**

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
# Create
movie = Movie(name='Guaridans of the Galaxy')
session.add(movie)
session.commit()

# %%
# Retreive

# Retrieve - Get 1 item by primary key
movie_a = session.get(Movie, 5)
if movie_a:
    print(f"ID: {movie_a.id}, Name: {movie_a.name}, Description: {movie_a.description}")
else:
    print("Movie with ID 5 not found")
# Out:
# Movie with ID 5 not found

# %%
# List
qs = session.query(Movie).all()
print(qs)
# Out:
# [<Movie name=Interstellar>, <Movie name=The Martian>, <Movie name=Inception>, <Movie name=Guaridans of the Galaxy>]

# %%
# List & Filter by Column Value
qs = session.query(Movie).filter_by(name='Guardians of the Galaxy').all()
qs
# Out:
# []

# %%
# List & Filter by Column Value Containing Something
qs = session.query(Movie).filter(Movie.name.contains("Guaridans")).all()
qs
# Out:
# [<Movie name=Guaridans of the Galaxy>]

# %%
# List & Filter by Column Value Containing Something
my_query = input("What are you looking for?\n") or "Unknown"
qs = session.query(Movie).filter(Movie.name.contains(my_query)).all()
print(qs)
# Out:
# What are you looking for?
#  the
# [<Movie name=The Martian>, <Movie name=Guaridans of the Galaxy>]

# %%
# Update

movie_a = session.get(Movie, 5)
movie_a.description = "A dream within a dream"
print(movie_a.id, movie_a.name, movie_a.description)
session.commit()
# Out:
# 5 Guaridans of the Galaxy A dream within a dream

# %%
movie_a = session.get(Movie, 5)
print(movie_a.description)
# Out:
# A dream within a dream

# %%
qs = session.query(Movie).filter(Movie.name.contains("Guaridans")).all()
for movie_obj in qs:
    movie_obj.name = "Guardians of the Galaxy"
session.commit()

# %%
qs = session.query(Movie).filter(Movie.name.contains("Guaridans")).all()
qs
# Out:
# []

# %%
# Delete
movie_a = session.get(Movie, 5)
session.delete(movie_a)
session.commit()

# %%
session.flush() #method that synchronizes your in-memory objects with the database, 
                 #but does not permanently commit the transaction.

# %% [markdown]
# ## SQLAlchemy & Pandas

# %%
# !sqlacodegen sqlite:///app2.db
# Out:
# from typing import Optional
#
# from sqlalchemy import Integer, String
# from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column
#
# class Base(DeclarativeBase):
#     pass
#
#
# class Movies(Base):
#     __tablename__ = 'movies'
#
#     id: Mapped[int] = mapped_column(Integer, primary_key=True)
#     name: Mapped[Optional[str]] = mapped_column(String)
#     genre: Mapped[Optional[str]] = mapped_column(String)
#     description: Mapped[Optional[str]] = mapped_column(String)
#     year: Mapped[Optional[int]] = mapped_column(Integer)

# %%
engine = create_engine("sqlite:///app2.db")
Session = sessionmaker(bind=engine)
session = Session()

# %%
from typing import Optional

from sqlalchemy import Integer, String
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column

class Base(DeclarativeBase):
    pass


class MoviesApp2(Base):
    __tablename__ = 'movies'

    id: Mapped[int] = mapped_column(Integer, primary_key=True)
    name: Mapped[Optional[str]] = mapped_column(String)
    genre: Mapped[Optional[str]] = mapped_column(String)
    description: Mapped[Optional[str]] = mapped_column(String)
    year: Mapped[Optional[int]] = mapped_column(Integer)

    def __repr__(self):
        return f"<Movie name={self.name}>"

# %%
qs = session.query(MoviesApp2).all()
print(qs)
# Out:
# [<Movie name=The Martian>, <Movie name=Inception>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name= Galaxy>, <Movie name= Galaxy>, <Movie name= Galaxy>, <Movie name=Guardians of the Galaxy>]

# %%
for old_obj in qs:
    movie_obj = Movie(name=old_obj.name, genre=old_obj.genre, year=old_obj.year)
    print(movie_obj.name)
    my_sess.add(movie_obj)
my_sess.commit()
qs = session.query(MoviesApp2).all()
print(qs)
# Out:
# The Martian
# Inception
# Guardians of the Galaxy
# Guardians of the Galaxy
# Guardians of the Galaxy
# Guardians of the Galaxy
# Guardians of the Galaxy
#  Galaxy
#  Galaxy
#  Galaxy
# Guardians of the Galaxy
# [<Movie name=The Martian>, <Movie name=Inception>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name=Guardians of the Galaxy>, <Movie name= Galaxy>, <Movie name= Galaxy>, <Movie name= Galaxy>, <Movie name=Guardians of the Galaxy>]

# %%
old_engine = create_engine("sqlite:///app2.db")
old_df = pd.read_sql_table("movies", old_engine)
old_df.head(n=15)
# Out:
#     id                     name   genre description  year
# 0    2              The Martian  Sci-Fi         NaN  None
# 1    3                Inception  Sci-Fi         NaN  None
# 2    4  Guardians of the Galaxy     NaN         NaN  None
# 3    6  Guardians of the Galaxy     NaN         NaN  None
# 4    7  Guardians of the Galaxy     NaN         NaN  None
# 5    8  Guardians of the Galaxy     NaN         NaN  None
# 6    9  Guardians of the Galaxy     NaN         NaN  None
# 7   10                   Galaxy     NaN         NaN  None
# 8   11                   Galaxy     NaN         NaN  None
# 9   12                   Galaxy     NaN         NaN  None
# 10  13  Guardians of the Galaxy     NaN         NaN  None

# %%
current_engine = create_engine("sqlite:///app.db")
current_df = pd.read_sql_table("movies", current_engine)
current_df.head()
# Out:
#    id                     name   genre description  year
# 0   2              The Martian  Sci-Fi         NaN  None
# 1   3                Inception  Sci-Fi         NaN  None
# 2   4  Guardians of the Galaxy     NaN         NaN  None
# 3   6  Guardians of the Galaxy     NaN         NaN  None
# 4   7  Guardians of the Galaxy     NaN         NaN  None

# %%
final_df = pd.concat([current_df, old_df])
final_df.head(n=20)
# Out:
#     id                     name   genre description  year
# 0    2              The Martian  Sci-Fi         NaN  None
# 1    3                Inception  Sci-Fi         NaN  None
# 2    4  Guardians of the Galaxy     NaN         NaN  None
# 3    6  Guardians of the Galaxy     NaN         NaN  None
# 4    7  Guardians of the Galaxy     NaN         NaN  None
# 5    8  Guardians of the Galaxy     NaN         NaN  None
# 6    9  Guardians of the Galaxy     NaN         NaN  None
# 7   10                   Galaxy     NaN         NaN  None
# 8   11                   Galaxy     NaN         NaN  None
# 9   12                   Galaxy     NaN         NaN  None
# 10  13  Guardians of the Galaxy     NaN         NaN  None
# 11  14              The Martian  Sci-Fi         NaN  None
# 12  15                Inception  Sci-Fi         NaN  None
# 13  16  Guardians of the Galaxy     NaN         NaN  None
# 14  17  Guardians of the Galaxy     NaN         NaN  None
# 15  18  Guardians of the Galaxy     NaN         NaN  None
# 16  19  Guardians of the Galaxy     NaN         NaN  None
# 17  20  Guardians of the Galaxy     NaN         NaN  None
# 18  21                   Galaxy     NaN         NaN  None
# 19  22                   Galaxy     NaN         NaN  None

# %%
final_df = final_df[['name', 'genre', 'description', 'year']] #remove IDs
final_df.reset_index(inplace=True, drop=True)
final_df.head(n=20)
# Out:
#                        name   genre description  year
# 0               The Martian  Sci-Fi         NaN  None
# 1                 Inception  Sci-Fi         NaN  None
# 2   Guardians of the Galaxy     NaN         NaN  None
# 3   Guardians of the Galaxy     NaN         NaN  None
# 4   Guardians of the Galaxy     NaN         NaN  None
# 5   Guardians of the Galaxy     NaN         NaN  None
# 6   Guardians of the Galaxy     NaN         NaN  None
# 7                    Galaxy     NaN         NaN  None
# 8                    Galaxy     NaN         NaN  None
# 9                    Galaxy     NaN         NaN  None
# 10  Guardians of the Galaxy     NaN         NaN  None
# 11              The Martian  Sci-Fi         NaN  None
# 12                Inception  Sci-Fi         NaN  None
# 13  Guardians of the Galaxy     NaN         NaN  None
# 14  Guardians of the Galaxy     NaN         NaN  None
# 15  Guardians of the Galaxy     NaN         NaN  None
# 16  Guardians of the Galaxy     NaN         NaN  None
# 17  Guardians of the Galaxy     NaN         NaN  None
# 18                   Galaxy     NaN         NaN  None
# 19                   Galaxy     NaN         NaN  None

# %%
final_df.to_sql(
    "new_movies", #new table name
    current_engine,
    if_exists='replace',#if table exists ?
    dtype = {
        "name": String,
        "genre": String,
        "year": Integer,
        "description": String,
    }
)
# Out:
# 44

# %%
! sqlacodegen sqlite:///app.db
# Out:
# from sqlalchemy import BigInteger, Column, Index, Integer, MetaData, String, Table
#
# metadata = MetaData()
#
#
# t_movies = Table(
#     'movies', metadata,
#     Column('index', BigInteger),
#     Column('name', String),
#     Column('genre', String),
#     Column('description', String),
#     Column('year', Integer),
#     Index('ix_movies_index', 'index')
# )
#
#
# t_new_movies = Table(
#     'new_movies', metadata,
#     Column('index', BigInteger),
#     Column('name', String),
#     Column('genre', String),
#     Column('description', String),
#     Column('year', Integer),
#     Index('ix_new_movies_index', 'index')
# )

# %%
import sqlite3


connection = sqlite3.connect('app.db')
connection2 = create_engine("sqlite:///app.db")

df = pd.read_sql_query("SELECT * FROM movies", connection2)
df.head()
# Out:
#    index                     name   genre description  year
# 0      0              The Martian  Sci-Fi        None  None
# 1      1                Inception  Sci-Fi        None  None
# 2      2  Guardians of the Galaxy     NaN        None  None
# 3      3  Guardians of the Galaxy     NaN        None  None
# 4      4  Guardians of the Galaxy     NaN        None  None
