# %%
import os
import pandas as pd

# %%
#Current working directory

cwd = os.getcwd() # dirname (abspath(file))
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')

# %%
os.listdir(DATA_DIR)
# Out:
# ['2020.csv',
#  '2021.csv',
#  '2023.csv',
#  '2022.csv',
#  '2026.csv',
#  '2025.csv',
#  '2024.csv']

# %%
my_data = os.path.join (DATA_DIR,'2019.csv')
print (os.path.exists(my_data))
# Out:
# False

# %%
my_data = os.path.join (DATA_DIR,'2026.csv')
print (os.path.exists(my_data))
# Out:
# True

# %%
df2 = pd.read_csv(my_data) #
df2.head(n=10), 
df2.tail(n=10)
# Out:
#      Rank                                      Release Group Worldwide  \
# 190   191                                             Hamlet  $587,326
# 191   192                             Traction Park Massacre  $570,368
# 192   193                      The Revenant 10th Anniversary  $563,943
# 193   194                                    Princess Stella  $517,437
# 194   195  The Metropolitan Opera HD Live: Vincenzo Belli...  $516,533
# 195   196                            Tripping With My Family  $506,909
# 196   197                                 My Father's Shadow  $480,346
# 197   198                             The Mortuary Assistant  $470,102
# 198   199  Fukuyama Masaharu raivu firumu@ Nagasaki gekko...  $469,150
# 199   200                                        Prakambanam  $460,175
#
#      Domestic      %   Foreign   %.1
# 190         -      -  $587,326  100%
# 191         -      -  $570,368  100%
# 192  $549,591  97.5%   $14,352  2.5%
# 193         -      -  $517,437  100%
# 194         -      -  $516,533  100%
# 195         -      -  $506,909  100%
# 196  $105,898    22%  $374,448   78%
# 197  $454,776  96.7%   $15,326  3.3%
# 198         -      -  $469,150  100%
# 199         -      -  $460,175  100%
