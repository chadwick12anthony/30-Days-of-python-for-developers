# %%
import os
import pandas as pd

# %%
#Current working directory

cwd = os.getcwd() # dirname (abspath(file))
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join (BASE_DIR,'cache')
os.makedirs(CACHE_DIR, exist_ok=True)

# %%
for filename in os.listdir(DATA_DIR) :
    print(filename)
# Out:
# 2020.csv
# 2021.csv
# 2023.csv
# 2022.csv
# 2026.csv
# 2025.csv
# 2024.csv

# %%
df = pd.read_csv(os.path.join(DATA_DIR, "2026.csv"))
df.head()
# Out:
#    Rank            Release Group     Worldwide      Domestic      %  \
# 0     1                Pegasus 3  $599,266,655    $1,374,946   0.2%
# 1     2        Wuthering Heights  $226,563,318   $82,163,318  36.3%
# 2     3                 Scream 7  $177,977,862  $107,577,862  60.4%
# 3     4                  Hoppers  $168,677,616   $90,618,975  53.7%
# 4     5  Blades of the Guardians  $168,462,054    $1,562,054   0.9%
#
#         Foreign    %.1
# 0  $597,891,709  99.8%
# 1  $144,400,000  63.7%
# 2   $70,400,000  39.6%
# 3   $78,058,641  46.3%
# 4  $166,900,000  99.1%

# %%
df["my approval"] = "Given"
df["year"] = "2021"
df.head()
# Out:
#    Rank            Release Group     Worldwide      Domestic      %  \
# 0     1                Pegasus 3  $599,266,655    $1,374,946   0.2%
# 1     2        Wuthering Heights  $226,563,318   $82,163,318  36.3%
# 2     3                 Scream 7  $177,977,862  $107,577,862  60.4%
# 3     4                  Hoppers  $168,677,616   $90,618,975  53.7%
# 4     5  Blades of the Guardians  $168,462,054    $1,562,054   0.9%
#
#         Foreign    %.1 my approval  year
# 0  $597,891,709  99.8%       Given  2021
# 1  $144,400,000  63.7%       Given  2021
# 2   $70,400,000  39.6%       Given  2021
# 3   $78,058,641  46.3%       Given  2021
# 4  $166,900,000  99.1%       Given  2021

# %%
my_entire_dataframe = pd.DataFrame()
csv_files = [x for x in os.listdir(DATA_DIR) if x.endswith(".csv") ]
my_dataframe = []

for filename in csv_files:
    print (filename, "\n")
    year = filename.replace(".csv", "")
    csv_path = os.path.join(DATA_DIR, filename)
    this_df = pd.read_csv(csv_path)
    this_df['filename'] = filename
    this_df['year'] = year
    print(this_df.head(n=1), "\n\n\n")
    my_dataframe.append(this_df)
# Out:
# 2020.csv
#
#    Rank                                      Release Group     Worldwide  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - The Movie: Mu...  $469,119,320
#
#       Domestic      %       Foreign    %.1  filename  year
# 0  $49,505,008  10.6%  $419,614,312  89.4%  2020.csv  2020
#
#
#
# 2021.csv
#
#    Rank            Release Group       Worldwide      Domestic      %  \
# 0     1  Spider-Man: No Way Home  $1,910,982,770  $804,793,477  42.1%
#
#           Foreign    %.1  filename  year
# 0  $1,106,189,293  57.9%  2021.csv  2021
#
#
#
# 2023.csv
#
#    Rank Release Group       Worldwide      Domestic    %       Foreign  %.1  \
# 0     1        Barbie  $1,447,138,421  $636,238,421  44%  $810,900,000  56%
#
#    filename  year
# 0  2023.csv  2023
#
#
#
# 2022.csv
#
#    Rank             Release Group       Worldwide      Domestic      %  \
# 0     1  Avatar: The Way of Water  $2,320,631,329  $684,075,767  29.5%
#
#           Foreign    %.1  filename  year
# ...

# %%
my_dataframe
# Out:
# [     Rank                                      Release Group     Worldwide  \
#  0       1  Demon Slayer: Kimetsu no Yaiba - The Movie: Mu...  $469,119,320
#  1       2                                  The Eight Hundred  $461,421,559
#  2       3                                  Bad Boys for Life  $426,505,244
#  3       4                             My People, My Homeland  $422,390,820
#  4       5                                              Tenet  $365,304,105
#  ..    ...                                                ...           ...
#  195   196                          The Broken Hearts Gallery    $4,781,389
#  196   197                         Gladiator 20th Anniversary    $4,780,585
#  197   198                                           Intruder    $4,751,103
#  198   199                      Paw Patrol: Jet to the Rescue    $4,693,664
#  199   200                                       Granny Nanny    $4,654,655
#
# ...

# %%
my_entire_dataframe = pd.concat(my_dataframe) # to combine many dataframes
my_entire_dataframe.head() , my_entire_dataframe.tail()
# Out:
# (   Rank                                      Release Group     Worldwide  \
#  0     1  Demon Slayer: Kimetsu no Yaiba - The Movie: Mu...  $469,119,320
#  1     2                                  The Eight Hundred  $461,421,559
#  2     3                                  Bad Boys for Life  $426,505,244
#  3     4                             My People, My Homeland  $422,390,820
#  4     5                                              Tenet  $365,304,105
#
#         Domestic      %       Foreign    %.1  filename  year
#  0   $49,505,008  10.6%  $419,614,312  89.4%  2020.csv  2020
#  1      $372,755  <0.1%  $461,048,804  99.9%  2020.csv  2020
#  2  $206,305,244  48.4%  $220,200,000  51.6%  2020.csv  2020
#  3             -      -  $422,390,820   100%  2020.csv  2020
#  4   $58,504,105    16%  $306,800,000    84%  2020.csv  2020  ,
#       Rank                                      Release Group   Worldwide  \
#  195   196  Uma Musume: Pretty Derby - Beginning of a New Era  $9,826,205
# ...

# %%
dataset = os.path.join(CACHE_DIR,'movies-box-office-dataset.csv')
my_entire_dataframe.to_csv(dataset, index = False)
