# %%
# !jupyter nbconvert --output-dir='../client' --to python Use_Access_Token.ipynb
# Out:
# [NbConvertApp] Converting notebook Use_Access_Token.ipynb to python
# [NbConvertApp] Writing 8615 bytes to ../client/Use_Access_Token.py
