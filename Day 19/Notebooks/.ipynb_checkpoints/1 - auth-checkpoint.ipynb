# %%
import base64
import datetime
import requests

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/anthonychadwick/.local/share/virtualenvs/Day_19-xCb6_Y8r/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthonychadwick/.local/share/virtualenvs/Day_19-xCb6_Y8r/lib/python3.11/site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anthonychadwick/.local/share/virtualenvs/Day_19-xCb6_Y8r/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthonychadwick/.local/share/virtualenvs/Day_19-xCb6_Y8r/lib/python3.11/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anthonychadwick/.local/share/virtualenvs/Day_19-xCb6_Y8r/lib/python3.11/site-packages (from requests) (2026.2.25)

# %%
client_id = '7131e680b1a7410db76dc664a5d1f4e8'
client_secret = 'caeb543cae33409ebc58ff5cd0ab860c'
method = 'POST'
token_url = ' https://accounts.spotify.com/api/token'

# %%
client_creds = f"{client_id}:{client_secret}"
type (client_creds)
# Out:
# str

# %%
client_creds_b64 = base64.b64encode(client_creds.encode())
type (client_creds_b64)

base64.b64decode (client_creds_b64)
# Out:
# b'7131e680b1a7410db76dc664a5d1f4e8:caeb543cae33409ebc58ff5cd0ab860c'

# %%
token_data = {
    "grant_type": "client_credentials"
}
token_headers = {
    "Authorization": f"Basic {client_creds_b64.decode()}" 
}# <base64 encoded client_id:client_se

# %%
r = requests.post(token_url, data=token_data, headers=token_headers)
print (r.json())
valid_request = r.status_code in range (200, 299)
# Out:
# {'access_token': 'BQCawaFNH_M0Im0TN3UAGk2JD_6UV7UoCV3OXvHBL61ObLAJgbXe3KJCJNPmtNosAeCi0WNe7082SPOEcVUJyvMs1_f1k8cc1t8LDJ2hvUZpZnNF3Zhkqqzveqah6W4jJ76o-Zyaj1g', 'token_type': 'Bearer', 'expires_in': 3600}

# %%
if valid_request :
    token_response_data = r.json()
    now = datetime.datetime.now()
    access_token = token_response_data['access_token']
    expires_in = token_response_data['expires_in'] # seconds
    expires = now + datetime.timedelta(seconds=expires_in)
    did_expire = expires < now
