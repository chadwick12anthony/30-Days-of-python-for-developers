# %%
import requests
from urllib.parse import urlencode

# %%
### First Steps
# 1. Sign up for Google Cloud
# 2. Create al Project Inside Google Cloud
# 3. Activate our API Services -> Geocoding API & Places API
# 4. Get API Key & Restrict

# %%
#key=API_KEY
api_key = 'AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw'

# %%
data_type = 'json'
endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
params = {"address": "1600 Amphitheatre Parkway, Mountain View, CA", "key": api_key}
url_params = urlencode(params)

url = f"{endpoint}?{url_params}"
print(url)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway%2C+Mountain+View%2C+CA&key=AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw

# %%
def extract_lat_lng(address_or_postalcode, data_type = 'json'):
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {"address": address_or_postalcode, "key": api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200, 299): 
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except:
        pass
    return latlng.get("lat"), latlng.get("lng")

# %%
extract_lat_lng("1600 Amphitheatre Parkway, Mountain View, CA")
# Out:
# (37.4225087, -122.0855442)

# %%
from urllib.parse import urlparse, parse_qsl
to_parse = 'https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway%2C+Mountain+View%2C+CA&key=AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw'

# %%
urlparse(to_parse)
# Out:
# ParseResult(scheme='https', netloc='maps.googleapis.com', path='/maps/api/geocode/json', params='', query='address=1600+Amphitheatre+Parkway%2C+Mountain+View%2C+CA&key=AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw', fragment='')

# %%
parsed_url = urlparse(to_parse)
query_string = parsed_url.query
query_string
# Out:
# 'address=1600+Amphitheatre+Parkway%2C+Mountain+View%2C+CA&key=AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw'

# %%
query_tuple = parse_qsl(query_string)
print(query_tuple)
# Out:
# [('address', '1600 Amphitheatre Parkway, Mountain View, CA'), ('key', 'AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw')]

# %%
query_dict = dict(query_tuple)
query_dict
# Out:
# {'address': '1600 Amphitheatre Parkway, Mountain View, CA',
#  'key': 'AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw'}

# %%
endpoint = f"{parsed_url.scheme}://{parsed_url.netloc}{parsed_url.path}"
print(endpoint)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json

# %%
lat, lng = 37.42230960000001, -122.0846244
base_endpoint_places = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
params = {
    "key": api_key,
    "input": "Mexican food",
    "inputtype": "textquery",
    "fields": "place_id,formatted_address,name,geometry,permanently_closed"
}
locationbias = f"point:{lat},{lng}"
use_cirular = True
if use_cirular:
    radius = 5000
    locationbias = f"circle:{radius}@{lat},{lng}"

params['locationbias'] = locationbias

params_encoded = urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyDh4XNVLZAsXdprF1ZZYIfoI0GGOsxUglw&input=Mexican+food&inputtype=textquery&fields=place_id%2Cformatted_address%2Cname%2Cgeometry%2Cpermanently_closed&locationbias=circle%3A5000%4037.42230960000001%2C-122.0846244

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r.json()
# Out:
# {'candidates': [{'formatted_address': '2483 Old Middlefield Way, Mountain View, CA 94043, Соединенные Штаты',
#    'geometry': {'location': {'lat': 37.4142988, 'lng': -122.0991715},
#     'viewport': {'northeast': {'lat': 37.41550142989272,
#       'lng': -122.0977730701073},
#      'southwest': {'lat': 37.41280177010727, 'lng': -122.1004727298928}}},
#    'name': 'Casa Mia Restaurant (Mountain View)',
#    'place_id': 'ChIJCza2IjC7j4ARf8iQuWMrTHw'}],
#  'status': 'OK'}

# %%
places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_2 = {
    "key": api_key,
    "location": f"{lat},{lng}",
    "radius": 1500,
    "keyword": "Mexican food"
}
params_2_encoded = urlencode(params_2)
places_url = f"{places_endpoint_2}?{params_2_encoded}"

r2 = requests.get(places_url)
r2.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.4142133, 'lng': -122.0936653},
#     'viewport': {'northeast': {'lat': 37.41554387989272,
#       'lng': -122.0923592201073},
#      'southwest': {'lat': 37.41284422010727, 'lng': -122.0950588798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'international_phone_number': '+1 650-439-8898',
#    'name': 'Paper Platez',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100187756684883327689">Larry Wu</a>'],
#      'photo_reference': 'AU_ZVEF4M6fot-5ESRlxn_1LJj3Yv-43UsZmBWcyeVqh03logFbIBTcuEaVD6YBYPg7W7KzcstxPCZl657Y7X3YwUQxGnT9K0ZlVFzEdzp0mU8frndmArSG5JaToIX9wi5c4e8ZTujQe40sHknoJPZJsyivzUTjjKbf7HNowtW7LH29TcLJljWLAxczenyTwvK8gKJzFom8eiRBs2eFgfHxO4wG_8bhLU5RGpnv4dK9E8gOFqfU8fJYP3g8W0N1YBjZCeBuKH_XETv-auXOevea5SeczdxmAHGoQ90ED_4jzAlke0mWYhm3gokVOMmZoAuWebyhiJTFI3wOPdKBpNloEyayw7r1H6u2UT0-uuwAsJr9NCkt5jHIgexBVZ44o5LI-maCzgCN6AIBI9gsPQvf2DIDEhufogfBTpO_3laq8jlJBvreCOv_zq-TyXYagbNS3MaKRnf0exFWpVvHgGxxKDxmCnVl22CB8RUhBFgp0qkp_PbdSv0Gtad2VrzDjXwLHkHs2fVKhx-3pGfyV0_AuwjhaBCVfa4TMUl-69ZhV9LcXm1NQtPIpshVbJjGB__E5qecXUpFP',
#      'width': 3072}],
#    'place_id': 'ChIJoeZn_jW7j4ARCGcxQXxyXJ0',
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJoeZn_jW7j4ARCGcxQXxyXJ0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total':

#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107597190036648627477">El Sabor de Michoacán Mexican Food</a>'],
#      'photo_reference': 'AU_ZVEEo31ULbeLOVDOMSknnbMCq4PAdhEW39pC40uxX_Kdztpksy-BmUFURBh6L_WIfiKmkFjpOvDm4GXTxi9xvAwi4bi6jYCTKOeVAi3p9DZukBF48QyGeFVqgbFTFLPG6XUHNvDzxlg1WaeDzYeLAKsb_n95DkfS-zPwz2IqBt66f-2hlcb7LW46s0fVuxbUiSRrcwOyyPxc26d6uOiqoX3ZCE3hHqDx59hzcPqJhawzUxUqzp4G6NCI0LcSyba8BZoRoZ8Yd8xpghvSjjunQ4VR14b568_BLeEIdxanyRmcsx18UVgvZc-PP6YWHc50I-i8jLJJsU3KUftlGLumFqLhu2SUCRoB0CelkBnDiVTtMJBtgfCQFhgGuhXp2jWXI9-FaIxIKpMxT3SJ-Onpx5_jKfjqD8phtYvI5WxGJJ02qMBJ0wpEZUHOYwnBK2R_C-RjedYgQFd90tvUErwBUG1q7YIpO6Q70DRzN9kswfU4hoYgWhbpZTKtOwIj2STmMEq1K-Rs44QXLfFhc5mYN0810Zztw1hb9Lujf0OJLhtSC4FiUToTjRbv-PH7qLQXqykneZdHTHWR63UnBIwN3d5AlZKVeVg',
#      'width': 1080}],
#    'place_id': 'ChIJx_NeGs27j4ARKfPtp4O-TUg',
#    'rating': 5,
#    'reference': 'ChIJx_NeGs27j4ARKfPtp4O-TUg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Leghorn st y, Rengstorff Ave, Mountain View'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.4146321, 'lng': -122.0896378},
#     'viewport': {'northeast': {'lat': 37.41595677989272,
#       'lng': -122.0883342201073},
#      'southwest': {'lat': 37.41325712010728, 'lng': -122.0910338798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'international_phone_number': '+1 650-495-0569',
#    'name': 'Margarita’s Taqueria (Mountain View) - Mexican Food Truck',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJVYvWfgC7j4ARFW6cWmQfrCg',
#    'price_level': 2,
#    'rating': 5,
#    'reference': 'ChIJVYvWfgC7j4ARFW6cWmQfrCg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '1950 Old Middlefield Way Corner, Mountain View'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.4218453, 'lng': -122.0965184},
#     'viewport': {'northeast': {'lat': 37.42317592989272,
#       'lng': -122.0952983701073},
#      'southwest': {'lat': 37.42047627010728, 'lng': -122.0979980298928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'international_phone_number': '+1 650-969-6528',
#    'name': 'Chipotle Mexican Grill',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106334976965814118540">Chipotle Mexican Grill</a>'],
#      'photo_reference': 'AU_ZVEH8sSpUl8WZwoXnJTRXIOS6drwHo6yXGsZoSrL3JCd-h-PFFxSmp8WT7DjiDu1s17RQOXtKV8_U3Jm2OAFY6PmDOgbdVS1MiMHUOeT8o9y1HyWBWNK5Tn_sE0lhGg0qLWVTK3KGCoI5Yf7A6pd-jQrqZUjGMiUXMU3Qha5Hj0HRYep_cxuRiLbjfuP4zIXjLLMVVehIYY_rGCdR3EBKNjwmmlXm5UrnZUMHURxDVQ9lYwjEP7cGLvAIkdq9OBXF_RxrdSJuII3MwXhdlJVsbriLPySO4KHBJzvvcu78YGTWXsDEEmqNMR8mdWgLfzsFGmJhxyH0vE9c52kO83tllL4idtmx6CWSk-AiQtW_JCCYc9KD6DIg6JY80moj7fMVf1cy109eiKfmf-Zo6FHKbl1ahOz3chMV8eNh2TrIg-AM6tzfXs7jKgCLZp0ikSiQbCi-1VM-17mqaAaq3kkOUhsSX9IsCXDznI4Jis1Jb0_nliNXen6qgCdjVxDdIo2vEZVKUBh64kjf6q1SI98K8etw1bvvO1N-EgfpbxyMbAej0Rd0RndS9COsnw3IQOe-od1btxn_lLE667OgwkTqaaf9Lr7S8g',
#      'width': 1000}],
#    'place_id': 'ChIJY1FiPRC6j4ARzhKBypjO7eg',
#    'price_level': 1,
#    'rating': 3.9,
#    'reference': 'ChIJY1FiPRC6j4ARzhKBypjO7eg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1080,
#    'vicinity': '2400 Charleston Rd, Mountain View'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.4150791, 'lng': -122.097056},
#     'viewport': {'northeast': {'lat': 37.41639467989272,
#       'lng': -122.0957376201073},
#      'southwest': {'lat': 37.41369502010728, 'lng': -122.0984372798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Sonora Taqueria',
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101576871126732767084">Mountain View Mrs</a>'],
#      'photo_reference': 'AU_ZVEGrtHD9aj1ZrWahJ8i6gPEkzSQXGlYwuYPmEGvNCverIbKEkPVHk_tvq7qHv6YISNORAVoqbzhEWvn8AUOrFdEarxq8lv6L-i1sTtQGC0zHdhA4T23KFe6krCGW_fCUIu1-luFbzPOKILQIzuAUVLI_Xx_qaLd7aSWoHmmihTIKmqHpho4NzX0GuRHSRlbjceI0gyMMTfHHcQzGQZ49o7Pv1LjaMKJC3RxvfNU2ozS277kwWCeyPzJ2hDslWswNFrOEQAaLCEtRdsC6ZNIWAqmlOp7lTnIJMdUaNvLM7uj5K-TeZruXYI1IaF4nzPnL0pGBYeoDWXwQ1wRTyrlLYPPEkUgcDXo9cQxMaVinTv8R5Rt-AGl-47vqDR6Z9W-TaxXrZqPZB3DolmqULrs639YrxzetpeDblB-WHX7vSRHYCCAsqktGc9wJP9X-qHC1tPWUoqUgJLOkQjtabuJPOm76SuJNJ9oro5nuXPslvPnVSLO_slV6ZhBtmZkfC9XyB-8Gt2g6PQk3sSGVqslkCjdY-51b-Z-e9LUYXDHD4bua-jvcQuveg0HE5mWOYWw_V19SPM2IOplt-JceHE2HuClY9lHf6Q',
#      'width': 2448}],
#    'place_id': 'ChIJmWkMVgC7j4ARTOSpHeEMCeQ',
#    'reference': 'ChIJmWkMVgC7j4ARTOSpHeEMCeQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '2378 Old Middlefield Way, Mountain View'}],
#  'status': 'OK'}

# %%
# detail_lookup
place_id = "ChIJlXOKcDC3j4ARzal-5j-p-FY"
detail_base_endpoint = "https://maps.googleapis.com/maps/api/place/details/json"
detail_params = {
    "place_id": f"{place_id}",
    "fields" : "name,rating,formatted_phone_number,formatted_address",
    "key": api_key
}

detail_params_encoded = urlencode(detail_params)

detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"

r = requests.get(detail_url)
r.json()
# Out:
# {'html_attributions': [],
#  'result': {'formatted_address': '240 Villa St, Mountain View, CA 94041, USA',
#   'formatted_phone_number': '(650) 968-1364',
#   'name': 'La Fiesta',
#   'rating': 4.4},
#  'status': 'OK'}
